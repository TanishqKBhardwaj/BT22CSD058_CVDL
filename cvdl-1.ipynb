# %%
import cv2

# %%
print(cv2.__version__)
# Out:
# 4.10.0

# %%
import matplotlib.pyplot as plt

# %%
img=cv2.imread('/kaggle/input/cvdl-1img/Profile_Picture_Leetcode.jpg')
plt.imshow(img)
plt.show()

# %%
img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img.shape
# Out:
# (1625, 1031, 3)

# %%
img_rgb.shape
# Out:
# (1625, 1031, 3)

# %%
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
plt.imshow(img,cmap='gray')

# %%
cv2.line(img,(1001,1601),(1001,1601),(255,11,0),)
plt.imshow(img)

# %%
cv2.circle(img,(1200,1200),(30),(255,255,11),10)
plt.imshow(img)

# %%
blur=cv2.GaussianBlur(img_rgb,(25, 25), 10.0)
plt.imshow(blur)
